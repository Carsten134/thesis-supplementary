# %%
import pandas as pd

from utils import plot_power_result

rej_blur = pd.read_csv("./sim_results/power/mc_per_band_ma_row.csv", usecols=["delta", "n", "decision"]).groupby(["n", "delta"]).mean()
rej_blur = rej_blur.reset_index()
plot_power_result(rej_blur)

# %%
rej_blur = pd.read_csv("./sim_results/power/mc_per_rot_alt.csv", usecols=["delta", "n", "decision"]).groupby(["n", "delta"]).mean()
rej_blur = rej_blur.reset_index()
plot_power_result(rej_blur)

# %%
rej_blur = pd.read_csv("./sim_results/power/mc_per_row_col_alt.csv", usecols=["delta", "n", "decision"]).groupby(["n", "delta"]).mean()
rej_blur = rej_blur.reset_index()
plot_power_result(rej_blur)

# %%
rej_blur = pd.read_csv("./sim_results/power/mc_per_blur_cor_alt.csv", usecols=["delta", "n", "decision"]).groupby(["n", "delta"]).mean()
rej_blur = rej_blur.reset_index()
plot_power_result(rej_blur)

# %%
import pandas as pd
from utils import plot_power_result

rej_blur_norm = pd.read_csv("./sim_results/power/mc_blur_alt_norm.csv", usecols=["delta", "n", "decision"]).groupby(["n", "delta"]).mean()
rej_blur_norm = rej_blur_norm.reset_index()
plot_power_result(rej_blur_norm)
